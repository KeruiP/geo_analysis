# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_geo=pd.read_csv('geo_platforms_table.csv')

# %%
ax=sns.countplot(x='Technology',data=df_geo)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()
